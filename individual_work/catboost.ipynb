# %%
# !pip install "u8darts[all]"
# !pip install catboost
# !pip install scikit-learn
# !pip install yfinance
# !pip install arch
# Out:
# Requirement already satisfied: u8darts[all] in c:\users\joelt\anaconda3\lib\site-packages (0.35.0)
# Requirement already satisfied: holidays>=0.11.1 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (0.74)
# Requirement already satisfied: joblib>=0.16.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (1.4.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (3.9.2)
# Requirement already satisfied: narwhals>=1.25.1 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (1.41.0)
# Requirement already satisfied: nfoursid>=1.0.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (1.0.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (1.26.4)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (2.2.2)
# Requirement already satisfied: pyod>=0.9.5 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (2.0.5)
# Requirement already satisfied: requests>=2.22.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (1.13.1)
# Requirement already satisfied: shap>=0.40.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (0.47.2)
# Requirement already satisfied: statsforecast>=1.4 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (2.0.1)
# Requirement already satisfied: statsmodels>=0.14.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (0.14.2)
# Requirement already satisfied: tqdm>=4.60.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (4.11.0)
# Requirement already satisfied: xarray>=0.17.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (2023.6.0)
# Requirement already satisfied: xgboost>=2.1.4 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (3.0.2)
# Requirement already satisfied: pytorch-lightning>=1.5.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (2.5.1.post0)
# Requirement already satisfied: tensorboardX>=2.1 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (2.6.2.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (2.7.0)
# Requirement already satisfied: prophet>=1.1.1 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (1.1.7)
# Requirement already satisfied: catboost>=1.0.6 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (1.2.8)
# Requirement already satisfied: lightgbm>=3.2.0 in c:\users\joelt\anaconda3\lib\site-packages (from u8darts[all]) (4.6.0)
# Requirement already satisfied: graphviz in c:\users\joelt\anaconda3\lib\site-packages (from catboost>=1.0.6->u8darts[all]) (0.20.3)
# Requirement already satisfied: plotly in c:\users\joelt\anaconda3\lib\site-packages (from catboost>=1.0.6->u8darts[all]) (5.24.1)
# Requirement already satisfied: six in c:\users\joelt\anaconda3\lib\site-packages (from catboost>=1.0.6->u8darts[all]) (1.16.0)
# Requirement already satisfied: python-dateutil in c:\users\joelt\anaconda3\lib\site-packages (from holidays>=0.11.1->u8darts[all]) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib>=3.3.0->u8darts[all]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib>=3.3.0->u8darts[all]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib>=3.3.0->u8darts[all]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib>=3.3.0->u8darts[all]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib>=3.3.0->u8darts[all]) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib>=3.3.0->u8darts[all]) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib>=3.3.0->u8darts[all]) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=1.0.5->u8darts[all]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=1.0.5->u8darts[all]) (2023.3)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\joelt\anaconda3\lib\site-packages (from prophet>=1.1.1->u8darts[all]) (1.2.5)
# Requirement already satisfied: importlib_resources in c:\users\joelt\anaconda3\lib\site-packages (from prophet>=1.1.1->u8darts[all]) (6.5.2)
# Requirement already satisfied: numba>=0.51 in c:\users\joelt\anaconda3\lib\site-packages (from pyod>=0.9.5->u8darts[all]) (0.60.0)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\joelt\anaconda3\lib\site-packages (from pytorch-lightning>=1.5.0->u8darts[all]) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\joelt\anaconda3\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->u8darts[all]) (2024.6.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in c:\users\joelt\anaconda3\lib\site-packages (from pytorch-lightning>=1.5.0->u8darts[all]) (1.7.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in c:\users\joelt\anaconda3\lib\site-packages (from pytorch-lightning>=1.5.0->u8darts[all]) (0.14.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joelt\anaconda3\lib\site-packages (from requests>=2.22.0->u8darts[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joelt\anaconda3\lib\site-packages (from requests>=2.22.0->u8darts[all]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joelt\anaconda3\lib\site-packages (from requests>=2.22.0->u8darts[all]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joelt\anaconda3\lib\site-packages (from requests>=2.22.0->u8darts[all]) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joelt\anaconda3\lib\site-packages (from scikit-learn>=1.6.0->u8darts[all]) (3.5.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\joelt\anaconda3\lib\site-packages (from shap>=0.40.0->u8darts[all]) (0.0.8)
# Requirement already satisfied: cloudpickle in c:\users\joelt\anaconda3\lib\site-packages (from shap>=0.40.0->u8darts[all]) (3.0.0)
# Requirement already satisfied: coreforecast>=0.0.12 in c:\users\joelt\anaconda3\lib\site-packages (from statsforecast>=1.4->u8darts[all]) (0.0.16)
# Requirement already satisfied: fugue>=0.8.1 in c:\users\joelt\anaconda3\lib\site-packages (from statsforecast>=1.4->u8darts[all]) (0.9.1)
# Requirement already satisfied: utilsforecast>=0.1.4 in c:\users\joelt\anaconda3\lib\site-packages (from statsforecast>=1.4->u8darts[all]) (0.2.12)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\joelt\anaconda3\lib\site-packages (from statsmodels>=0.14.0->u8darts[all]) (0.5.6)
# Requirement already satisfied: protobuf>=3.20 in c:\users\joelt\anaconda3\lib\site-packages (from tensorboardX>=2.1->u8darts[all]) (4.25.3)
# Requirement already satisfied: filelock in c:\users\joelt\anaconda3\lib\site-packages (from torch>=1.8.0->u8darts[all]) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\joelt\anaconda3\lib\site-packages (from torch>=1.8.0->u8darts[all]) (1.14.0)
# Requirement already satisfied: networkx in c:\users\joelt\anaconda3\lib\site-packages (from torch>=1.8.0->u8darts[all]) (3.3)
# Requirement already satisfied: jinja2 in c:\users\joelt\anaconda3\lib\site-packages (from torch>=1.8.0->u8darts[all]) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\joelt\anaconda3\lib\site-packages (from torch>=1.8.0->u8darts[all]) (75.1.0)
# Requirement already satisfied: colorama in c:\users\joelt\anaconda3\lib\site-packages (from tqdm>=4.60.0->u8darts[all]) (0.4.6)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\joelt\anaconda3\lib\site-packages (from cmdstanpy>=1.0.4->prophet>=1.1.1->u8darts[all]) (0.5.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\joelt\anaconda3\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->u8darts[all]) (3.10.5)
# Requirement already satisfied: triad>=0.9.7 in c:\users\joelt\anaconda3\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->u8darts[all]) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in c:\users\joelt\anaconda3\lib\site-packages (from fugue>=0.8.1->statsforecast>=1.4->u8darts[all]) (0.2.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\joelt\anaconda3\lib\site-packages (from numba>=0.51->pyod>=0.9.5->u8darts[all]) (0.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\joelt\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->u8darts[all]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joelt\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->u8darts[all]) (2.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\joelt\anaconda3\lib\site-packages (from plotly->catboost>=1.0.6->u8darts[all]) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\joelt\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->u8darts[all]) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\joelt\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->u8darts[all]) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\joelt\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->u8darts[all]) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\joelt\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->u8darts[all]) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\joelt\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->u8darts[all]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\joelt\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=1.5.0->u8darts[all]) (1.11.0)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\joelt\anaconda3\lib\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->u8darts[all]) (16.1.0)
# Requirement already satisfied: fs in c:\users\joelt\anaconda3\lib\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->u8darts[all]) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\joelt\anaconda3\lib\site-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->u8darts[all]) (1.4.4)
# Requirement already satisfied: catboost in c:\users\joelt\anaconda3\lib\site-packages (1.2.8)
# Requirement already satisfied: graphviz in c:\users\joelt\anaconda3\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\joelt\anaconda3\lib\site-packages (from catboost) (3.9.2)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\joelt\anaconda3\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\joelt\anaconda3\lib\site-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in c:\users\joelt\anaconda3\lib\site-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in c:\users\joelt\anaconda3\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\joelt\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\joelt\anaconda3\lib\site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\joelt\anaconda3\lib\site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: scikit-learn in c:\users\joelt\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\joelt\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\joelt\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\joelt\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joelt\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: yfinance in c:\users\joelt\anaconda3\lib\site-packages (0.2.63)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (0.11.3)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\joelt\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\joelt\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\joelt\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\joelt\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joelt\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joelt\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joelt\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\joelt\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\joelt\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: arch in c:\users\joelt\anaconda3\lib\site-packages (7.2.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\joelt\anaconda3\lib\site-packages (from arch) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in c:\users\joelt\anaconda3\lib\site-packages (from arch) (1.13.1)
# Requirement already satisfied: pandas>=1.4 in c:\users\joelt\anaconda3\lib\site-packages (from arch) (2.2.2)
# Requirement already satisfied: statsmodels>=0.12 in c:\users\joelt\anaconda3\lib\site-packages (from arch) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=1.4->arch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=1.4->arch) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joelt\anaconda3\lib\site-packages (from pandas>=1.4->arch) (2023.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\joelt\anaconda3\lib\site-packages (from statsmodels>=0.12->arch) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\joelt\anaconda3\lib\site-packages (from statsmodels>=0.12->arch) (24.1)
# Requirement already satisfied: six in c:\users\joelt\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.12->arch) (1.16.0)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# --- Ticker and Date Setup ---
tickers = ['AAPL', 'MSFT', 'NVDA', 'AMZN', 'GOOGL', 'META', 'TSLA', 'BRK-B', 'JPM', 'V']
start_date = '2010-01-01'
end_date = '2024-12-31'
train_end = '2023-12-31'
test_start = '2024-01-01'

# --- Download Data ---
data = yf.download(tickers, start=start_date, end=end_date)
close_data = data['Close'].copy()
log_close_data = np.log(close_data)
log_data = pd.concat([close_data, log_close_data], axis=1, keys=['Close', 'LogClose'])
# Out:
# C:\Users\joelt\AppData\Local\Temp\ipykernel_60656\3767500248.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  10 of 10 completed

# %%
# --- Parameters ---
max_lag = 5
target_returns = {}

# --- Create lagged features ---
logclose_df = log_data['LogClose']
feature_df = pd.DataFrame(index=logclose_df.index)

for t in tickers:
    for lag in range(1, max_lag + 1):
        feature_df[f"{t}_lag{lag}"] = logclose_df[t].shift(lag)

# %%
# --- Model training loop per ticker ---
results = {}

for t in tickers:
    print(f"\n📈 Training model for {t}")
    
    # Target: next-day log return
    feature_df[f"target_{t}"] = logclose_df[t].shift(-1) - logclose_df[t]

    model_data = feature_df.dropna()

    # Time-based split
    train = model_data.loc[:train_end]
    test = model_data.loc[test_start:]

    X_train = train.drop(columns=[f"target_{t}"])
    y_train = train[f"target_{t}"]

    X_test = test.drop(columns=[f"target_{t}"])
    y_test = test[f"target_{t}"]
    # CatBoost Model
    model = CatBoostRegressor(
        iterations=500,
        learning_rate=0.05,
        depth=6,
        verbose=0,
        loss_function='RMSE'
    )
    model.fit(X_train, y_train)

    # Predict and evaluate
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    print(f"✅ {t} RMSE: {rmse:.6f}")

    # Store results
    results[t] = {
        'model': model,
        'rmse': rmse,
        'y_test': y_test,
        'y_pred': pd.Series(y_pred, index=y_test.index)
    }
# Out:
# 📈 Training model for AAPL
# ✅ AAPL RMSE: 0.015074
#
# 📈 Training model for MSFT
# ✅ MSFT RMSE: 0.011251
#
# 📈 Training model for NVDA
# ✅ NVDA RMSE: 0.030358
#
# 📈 Training model for AMZN
# ✅ AMZN RMSE: 0.014709
#
# 📈 Training model for GOOGL
# ✅ GOOGL RMSE: 0.014105
#
# 📈 Training model for META
# ✅ META RMSE: 0.019523
#
# 📈 Training model for TSLA
# ✅ TSLA RMSE: 0.038336
#
# 📈 Training model for BRK-B
# ✅ BRK-B RMSE: 0.009729
#
# 📈 Training model for JPM
# ✅ JPM RMSE: 0.011997
#
# 📈 Training model for V
# ✅ V RMSE: 0.010601
